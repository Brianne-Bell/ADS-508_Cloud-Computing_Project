# %% [markdown]
# # Run Ad-Hoc Data Bias Analysis

# %%
from smclarify.bias import report
from typing import Dict
from collections import defaultdict
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Read Dataset From S3

# %%
# %store -r bias_data_s3_uri

# %%
print(bias_data_s3_uri)
# Out:
# s3://ads-508-team4/bias-detection-1647856853/master_unbal.csv

# %%
# %store -r balanced_bias_data_s3_uri

# %%
print(balanced_bias_data_s3_uri)
# Out:
# s3://ads-508-team4/bias-detection-1647856853/master_bal.csv

# %%
# !aws s3 cp $bias_data_s3_uri ./data-clarify/
# Out:
# download: s3://ads-508-team4/bias-detection-1647856853/master_unbal.csv to data-clarify/master_unbal.csv

# %%
# !aws s3 cp $balanced_bias_data_s3_uri ./data-clarify/
# Out:
# download: s3://ads-508-team4/bias-detection-1647856853/master_bal.csv to data-clarify/master_bal.csv

# %%
df = pd.read_csv("./data-clarify/master_bal.csv")
df.shape
# Out:
# (17472, 2)

# %% [markdown]
# # Calculate Bias Metrics on Unbalanced Data

# %%
facet_column = report.FacetColumn(name='"product_category_name"')

label_column = report.LabelColumn(
    name='"price"', 
    data=df['"price"'],
    positive_label_values=[150, ]
)

# %% [markdown]
# # Run SageMaker Clarify Bias Report

# %%
report.bias_report(
    df=df, 
    facet_column=facet_column, 
    label_column=label_column, 
    stage_type=report.StageType.PRE_TRAINING, 
    metrics=["CI", "DPL", "KL", "JS", "LP", "TVD", "KS"]
)
# Out:
# [{'value_or_threshold': 'agro_industria_e_comercio',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9896978021978022},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.22074176351014452},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.04972970448491889},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.09854273045130943},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.22074176351014457},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.3121759957382008},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.22074176351014455}]},
#  {'value_or_threshold': 'alimentos',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9869505494505495},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.2810595448177998},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.10665158705376593},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.31325778813409066},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.2810595448177998},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.39747822011574113},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.28105954481779977}]},
#  {'value_or_threshold': 'alimentos_bebidas',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9887820512820513},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.29862355901264614},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.1244157738758301},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.3922438318449044},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.29862355901264614},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.42231748719980644},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.29862355901264614}]},
#  {'value_or_threshold': 'artes',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9922161172161172},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.2709924696148282},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.0982355310654857},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.27833224544834734},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.27099246961482826},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.38324122583026893},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.27099246961482826}]},
#  {'value_or_threshold': 'artes_e_artesanato',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9978250915750916},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.2531852463910593},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.08417062838091365},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.2258087020244134},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.2531852463910593},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.3580580092390098},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.2531852463910593}]},
#  {'value_or_threshold': 'artigos_de_festas',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9975961538461539},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.12022233682883504},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.01672188763791553},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.036267052094639984},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.12022233682883504},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.1700200592435249},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.12022233682883501}]},
#  {'value_or_threshold': 'artigos_de_natal',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.993246336996337},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.2743537606327632},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.10133051066184832},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.29014894738946506},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.2743537606327632},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.3879948091749154},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.2743537606327632}]},
#  {'value_or_threshold': 'audio',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9908424908424909},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.01690432382704693},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.00030587945207234137},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.0006134372486690971},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.01690432382704693},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.02390632401895639},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.016904323827046902}]},
#  {'value_or_threshold': 'automotivo',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9005265567765568},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.016648037390056714},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.00027121206101514265},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.0005955940072754316},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.016648037390056714},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.02354388026391259},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.016648037390056714}]},
#  {'value_or_threshold': 'bebes',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9403617216117216},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0

#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.990728021978022},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.00014907668291602727},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 2.3946849398157688e-08},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 4.8342765340711425e-08},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.00014907668291602727},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.0002108262668134},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.00014907668291599951}]},
#  {'value_or_threshold': 'informatica_acessorios',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.8851877289377289},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.07060596097432398},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.004722194611833219},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.010389763648455341},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.07060596097432398},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.0998519075942744},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.07060596097432395}]},
#  {'value_or_threshold': 'instrumentos_musicais',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9685210622710623},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.20505436994824683},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.0420894024908945},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.08492659700309946},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.20505436994824683},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.2899906710046807},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.20505436994824683}]},
#  {'value_or_threshold': 'la_cuisine',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9986263736263736},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.10824742268041238},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.013463528688695629},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.028853939142284846},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.10824742268041238},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.1530849732465721},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.10824742268041235}]},
#  {'value_or_threshold': 'livros_importados',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9969093406593407},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.28453870895831346},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.11129627607014557},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.33010375807355463},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.28453870895831346},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.40239850122897775},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.28453870895831346}]},
#  {'value_or_threshold': 'livros_interesse_geral',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9832875457875457},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.27139985989857673},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.097536010670569},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.2777553263975827},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.27139985989857673},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.383817362694725},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.2713998598985767}]},
#  {'value_or_threshold': 'livros_tecnicos',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9880952380952381},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.24424228466144635},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.076559076970843},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.20191663103211932},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.24424228466144635},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.34541075147320754},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.24424228466144632}]},
#  {'value_or_threshold': 'malas_acessorios',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9719551282051282},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.032092479413545205},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.0011043590421440856},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.0023048943922020365},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.032092479413545205},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.04538561963681498},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.032092479413545205}]},
#  {'value_or_threshold': 'market_place',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9879807692307693},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.11122243335060744},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.014085047275388514},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.030562738819378737},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.11122243335060744},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.1572922736845667},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.11122243335060744}]},
#  {'value_or_threshold': 'moveis_colchao_e_estofado',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9989697802197802},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.13602092042222608},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.02167657923526172},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.04770751206416811},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.13602092042222608},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.1923626304275836},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.13602092042222605}]},
#  {'value_or_threshold': 'moveis_cozinha_area_de_servico_jantar_e_jardim',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9888965201465202},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.0856011273455462},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.007655555506371406},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.015122649299868021},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.08560112734554626},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.1210582752464979},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.08560112734554623}]},
#  {'value_or_threshold': 'moveis_decoracao',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9097985347985348},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.05347839262395537},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.002909624193051362},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.00652632515621817},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.05347839262395537},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.07562986814271098},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.05347839262395537}]},
#  {'value_or_threshold': 'moveis_escritorio',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9768772893772893},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.18355300498202692},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.03409586002093144},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.06803353038328652},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.18355300498202692},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.2595831490599187},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.18355300498202687}]},
#  {'value_or_threshold': 'moveis_quarto',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9953067765567766},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.27662238988289717},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.07831228896934937},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.15688687850833402},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.2766223898828972},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.39120313542845125},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.2766223898828972}]},
#  {'value_or_threshold': 'moveis_sala',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9837454212454212},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.020309972936290555},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.0004451925146853298},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.000913084799649147},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.020309972936290555},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.028722639177932614},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.020309972936290555}]},
#  {'value_or_threshold': 'musica',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9970238095238095},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.1661125759486415},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.03302918522150204},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.07543362620705149},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.1661125759486416},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.23491865778729967},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.16611257594864154}]},
#  {'value_or_threshold': 'papelaria',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9554716117216118},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.10866438123740929},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.012978065478220275},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.028950624093966024},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.10866438123740929},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.15367464169282471},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.10866438123740929}]},
#  {'value_or_threshold': 'pc_gamer',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9996565934065934},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.30854656820653725},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.09789533732040147},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.19805346046921454},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.3085465682065373},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.43635074138136026},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.30854656820653725}]},
#  {'value_or_threshold': 'pcs',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9959935897435898},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.6144864368870793},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.44016788768588244},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 1.6450029173148613},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.6144864368870793},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.8690150529400263},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.6144864368870793}]},
#  {'value_or_threshold': 'perfumaria',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.929945054945055},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.041990556602237605},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.0017608390533206302},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.0037263909848482824},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.041990556602237605},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.05938361463847953},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.041990556602237605}]},
#  {'value_or_threshold': 'pet_shop',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.946771978021978},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.08517100169379971},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.007791763910724884},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.01720837190830768},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.08517100169379971},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.12044998571627336},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.08517100169379968}]},
#  {'value_or_threshold': 'portateis_casa_forno_e_cafe',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9956501831501832},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.11576290732567335},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.013988177608398981},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.027351857118414882},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.1157629073256734},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.163713473559707},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.11576290732567338}]},
#  {'value_or_threshold': 'portateis_cozinha_e_preparadores_de_alimentos',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9988553113553114},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.05820639102050168},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.003781503978200845},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.007803222633657084},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.05820639102050168},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.08231626759798498},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.05820639102050165}]},
#  {'value_or_threshold': 'relogios_presentes',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.90121336996337},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.35580940878149864},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.11822627985470827},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.26785651808248967},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.35580940878149875},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.5031904915187481},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.3558094087814987}]},
#  {'value_or_threshold': 'seguros_e_servicos',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9997710622710623},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.1418431597023469},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.020970299050929057},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.040796851778930346},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.1418431597023469},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.2005965201809118},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.14184315970234687}]},
#  {'value_or_threshold': 'sinalizacao_e_seguranca',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9892399267399268},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.11410612096977593},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.014872342634950676},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.03231736829974767},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.11410612096977593},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.1613704238252421},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.11410612096977592}]},
#  {'value_or_threshold': 'tablets_impressao_imagem',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9981684981684982},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.23338680109990834},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.06978966700118493},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.17843553948190896},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.2333868010999084},
#    {'name': 'LP', 'description': 'L-p Norm (LP)', 'value': 0.3300587793943624},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.23338680109990836}]},
#  {'value_or_threshold': 'telefonia',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9491758241758241},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.046286243960662554},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.002260221267670896},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.004860180007687738},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.046286243960662554},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.06545863396047871},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.046286243960662526}]},
#  {'value_or_threshold': 'telefonia_fixa',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.9883241758241759},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': -0.02432185309356899},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.000629875564841385},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.0012632246948076457},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.024321853093569046},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.03439629450697132},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.024321853093569018}]},
#  {'value_or_threshold': 'utilidades_domesticas',
#   'metrics': [{'name': 'CI',
#     'description': 'Class Imbalance (CI)',
#     'value': 0.8729395604395604},
#    {'name': 'DPL',
#     'description': 'Difference in Positive Proportions in Labels (DPL)',
#     'value': 0.0832839440100166},
#    {'name': 'JS',
#     'description': 'Jensen-Shannon Divergence (JS)',
#     'value': 0.006901854259806892},
#    {'name': 'KL',
#     'description': 'Kullback-Liebler Divergence (KL)',
#     'value': 0.016322155598683954},
#    {'name': 'KS',
#     'description': 'Kolmogorov-Smirnov Distance (KS)',
#     'value': 0.0832839440100166},
#    {'name': 'LP',
#     'description': 'L-p Norm (LP)',
#     'value': 0.11778128314688696},
#    {'name': 'TVD',
#     'description': 'Total Variation Distance (TVD)',
#     'value': 0.0832839440100166}]}]

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
